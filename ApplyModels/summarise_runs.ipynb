# %%
from __future__ import division
import pandas as pd
import numpy as np
import gzip
import cPickle as pickle

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

pd.set_option('display.precision', 2)

# %% [markdown]
# Measures I'd like to have:
#
# * acc | mrr | acv | rnd , for rel and no rel
# * for rel: how much has been dropped? (Probably easiest if both is one line.)
# * **acc as function of utterance length (for bins, 1-2, 2-3, 4-, ?)**
# * as function of vocab size? (Ok, that would have to be done as separate eval, only summarised here)

# %%
def is_iou_over_threshold_top_n(row, threshold=0.5, n=1, random=False):
    if np.isnan(row['nob']):
        return np.nan
    if random:
        return np.any(np.array(row['ious'])[np.random.choice(range(len(row['ious'])), n)] > threshold)
    return np.any(np.array(row['ious'])[row['rnk']][:n] > threshold)

# %%
with gzip.open('EvalOut/results-20160313.pklz', 'r') as f:
    results = pickle.load(f)

# %%
with gzip.open('EvalOut/results-top20.pklz', 'r') as f:
    results.extend(pickle.load(f))

# %%
with gzip.open('EvalOut/results-rprops2.pklz', 'r') as f:
    results.extend(pickle.load(f))

# %%
with gzip.open('EvalOut/results-cutoff.pklz', 'r') as f:
    results.extend(pickle.load(f))

# %%
len(results)
# Out:
# 35

# %%
[m for m,_ in results]
# Out:
# ['01_s5r; add',
#  '01_s5r; mult',
#  '01_s5r; hmean',
#  '02_s5s; add',
#  '02_s5s; mult',
#  '02_s5s; hmean',
#  '03_r5r; mult',
#  '03_r5r->gr; mult',
#  '04_g5r; mult',
#  '04_g5r->rc; mult',
#  '05_sr5r->s; mult',
#  '05_sr5r->r; mult',
#  '05_sr5r->g; mult',
#  '10_srg5r->s; mult',
#  '10_srg5r->r; mult',
#  '10_srg5r->g; mult',
#  '11_rg5r->s; mult',
#  '11_rg5r->r; mult',
#  '11_rg5r->g; mult',
#  'max area; s',
#  'max area; c',
#  '06_pos_s5r; mult',
#  '07_nopos_s5r; mult',
#  '08_pos_r5r; mult',
#  '09_nopos_r5r; mult',
#  '01_s5r; brprop; mult',
#  '05_sr5r; brprop; mult',
#  '03_r5r; grprop; mult',
#  '09_nopos_r5r; grprop; mult',
#  '08_pos_r5r; grprop; mult',
#  '01_s5r; mult; top20',
#  '03_r5r; mult; top20',
#  '04_g5r; mult; top20',
#  '04_g5r; grprop; mult',
#  '01_co75_s5r; mult']

# %%
res_dict = {m:df for m,df in results}

# %%
def mrr_f(series):
    return np.mean(series.apply(lambda x:(1/x)))
def acc_f(series):
    return np.count_nonzero(np.nan_to_num(series.tolist())) / len(series)

# %%
def summarise_rdf(rdf):
    this_row = {}
    # for the full data frame
    this_row['acc-full'] = acc_f(rdf['suc'])
    this_row['mrr-full'] = mrr_f(rdf['rnk'])
    this_row['arc-full'] = rdf['cov'].mean()
    this_row['rnd-full'] = mrr_f(rdf['nob'])
    # for the ones where at least one word was known
    nz_rdf = rdf.query('cov > 0')
    this_row['>0 wrcov'] = len(nz_rdf) / len(rdf)
    this_row['acc->0wc'] = acc_f(nz_rdf['suc'])
    this_row['mrr->0wc'] = mrr_f(nz_rdf['rnk'])
    this_row['arc->0wc'] = nz_rdf['cov'].mean()
    this_row['rnd->0wc'] = mrr_f(nz_rdf['nob'])
    # binned by refexp length
    lens = nz_rdf['refexp'].apply(lambda x: len(x.split()))
    this_bin = nz_rdf[(lens > 0) & (lens <= 2)]
    this_row['acc-b1-2'] = acc_f(this_bin['suc'])
    this_row['12%'] = len(this_bin) / len(nz_rdf)
    this_bin = nz_rdf[(lens > 2) & (lens <= 4)]
    this_row['acc-b3-4'] = acc_f(this_bin['suc'])
    this_row['34%'] = len(this_bin) / len(nz_rdf)
    this_bin = nz_rdf[(lens > 4) & (lens <= 6)]
    this_row['acc-b5-6'] = acc_f(this_bin['suc'])
    this_row['56%'] = len(this_bin) / len(nz_rdf)
    return this_row

def summarise_rdf_rprop(rdf):
    this_row = {}
    # for the full data frame
    this_row['RP@1-full'] = acc_f(rdf.apply(is_iou_over_threshold_top_n, axis=1))
    this_row['RP@10-full'] = acc_f(rdf.apply(lambda x:is_iou_over_threshold_top_n(x, n=10), 
                                           axis=1))
    this_row['arc-full'] = rdf['cov'].mean()
    this_row['rnd-full'] = acc_f(rdf.apply(lambda x:is_iou_over_threshold_top_n(x, random=True), 
                                           axis=1))
    # for the ones where at least one word was known
    nz_rdf = rdf.query('cov > 0')
    this_row['>0 wrcov'] = len(nz_rdf) / len(rdf)
    this_row['RP@1->0wc'] = acc_f(nz_rdf.apply(is_iou_over_threshold_top_n, axis=1))
    this_row['RP@10->0wc'] = acc_f(nz_rdf.apply(lambda x:is_iou_over_threshold_top_n(x, n=10), 
                                               axis=1))
    this_row['arc->0wc'] = nz_rdf['cov'].mean()
    this_row['rnd->0wc'] = acc_f(nz_rdf.apply(lambda x:is_iou_over_threshold_top_n(x, random=True), 
                                           axis=1))
    return this_row

# %%
index = []
rows = []
for model, rdf in results:
    if 'rprop' in model:
        continue
        # rows.append(summarise_rdf_rprop(rdf))
    else:
        index.append(model)
        this_resdict = summarise_rdf(rdf)
        this_resdict['%tst'] = 1.0
        rows.append(this_resdict)
        index.append(model + '; NR')
        rdf_norel = rdf.query('is_rel == False')
        this_resdict = summarise_rdf(rdf_norel)
        this_resdict['%tst'] = len(rdf_norel) / len(rdf)
        rows.append(this_resdict)

collected_columns = {}
for this_row in rows:
    for this_key, this_val in this_row.items():
        this_list = collected_columns.get(this_key, list())
        this_list.append(this_val)
        collected_columns[this_key] = this_list
        
full_df = pd.DataFrame(collected_columns, index=index)
full_df = full_df[['%tst', 'acc-full', 'mrr-full', 'arc-full', 'rnd-full', '>0 wrcov', 
                   'acc->0wc', 'mrr->0wc', 'arc->0wc', 'rnd->0wc',
                   'acc-b1-2', '12%', 'acc-b3-4', '34%', 'acc-b5-6', '56%']]

# %%
pd.set_option('display.float_format', '{:.2f}'.format)
full_df
# Out:
#                          %tst  acc-full  mrr-full  arc-full  rnd-full  \
# 01_s5r; add              1.00      0.62      0.77      0.89      0.20
# 01_s5r; add; NR          0.86      0.66      0.80      0.91      0.20
# 01_s5r; mult             1.00      0.65      0.79      0.89      0.20
# 01_s5r; mult; NR         0.86      0.68      0.82      0.91      0.20
# 01_s5r; hmean            1.00      0.62      0.77      0.89      0.20
# 01_s5r; hmean; NR        0.86      0.66      0.80      0.91      0.20
# 02_s5s; add              1.00      0.60      0.76      0.89      0.20
# 02_s5s; add; NR          0.86      0.64      0.79      0.91      0.20
# 02_s5s; mult             1.00      0.63      0.78      0.89      0.20
# 02_s5s; mult; NR         0.86      0.67      0.81      0.91      0.20
# 02_s5s; hmean            1.00      0.61      0.76      0.89      0.20
# 02_s5s; hmean; NR        0.86      0.65      0.79      0.91      0.20
# 03_r5r; mult             1.00      0.61      0.77      0.91      0.16
# 03_r5r; mult; NR         0.94      0.63      0.78      0.92      0.16
# 03_r5r->gr; mult         1.00      0.46      0.68      0.80      0.19
# 03_r5r->gr; mult; NR     0.82      0.48      0.69      0.82      0.19
# 04_g5r; mult             1.00      0.43      0.65      0.86      0.19
# 04_g5r; mult; NR         0.82      0.45      0.67      0.88      0.19
# 04_g5r->rc; mult         1.00      0.48      0.68      0.90      0.16
# 04_g5r->rc; mult; NR     0.94      0.49      0.69      0.91      0.16
# 05_sr5r->s; mult         1.00      0.63      0.77      0.91      0.20
# 05_sr5r->s; mult; NR     0.86      0.67      0.81      0.93      0.20
# 05_sr5r->r; mult         1.00      0.63      0.78      0.92      0.16
# 05_sr5r->r; mult; NR     0.94      0.65      0.79      0.93      0.16
# 05_sr5r->g; mult         1.00      0.44      0.66      0.84      0.19
# 05_sr5r->g; mult; NR     0.82      0.46      0.67      0.85      0.19
# 10_srg5r->s; mult        1.00      0.62      0.76      0.92      0.20
# 10_srg5r->s; mult; NR    0.86      0.66      0.80      0.94      0.20
# 10_srg5r->r; mult        1.00      0.63      0.78      0.94      0.16
# 10_srg5r->r; mult; NR    0.94      0.65      0.79      0.95      0.16
# 10_srg5r->g; mult        1.00      0.47      0.68      0.90      0.19
# 10_srg5r->g; mult; NR    0.82      0.49      0.70      0.91      0.19
# 11_rg5r->s; mult         1.00      0.28      0.52      0.72      0.19
# 11_rg5r->s; mult; NR     0.86      0.30      0.55      0.72      0.19
# 11_rg5r->r; mult         1.00      0.62      0.78      0.93      0.16
# 11_rg5r->r; mult; NR     0.94      0.64      0.79      0.94      0.16
# 11_rg5r->g; mult         1.00      0.47      0.68      0.88      0.19
# 11_rg5r->g; mult; NR     0.82      0.49      0.69      0.90      0.19
# max area; s              1.00      0.19      0.41      1.00      0.20
# max area; s; NR          0.86      0.20      0.43      1.00      0.20
# max area; c              1.00      0.27      0.54      1.00      0.16
# max area; c; NR          0.94      0.28      0.55      1.00      0.16
# 06_pos_s5r; mult         1.00      0.60      0.76      0.89      0.20
# 06_pos_s5r; mult; NR     0.86      0.62      0.78      0.91      0.20
# 07_nopos_s5r; mult       1.00      0.53      0.71      0.89      0.20
# 07_nopos_s5r; mult; NR   0.86      0.56      0.73      0.91      0.20
# 08_pos_r5r; mult         1.00      0.55      0.74      0.91      0.16
# 08_pos_r5r; mult; NR     0.94      0.57      0.75      0.92      0.16
# 09_nopos_r5r; mult       1.00      0.44      0.66      0.91      0.16
# 09_nopos_r5r; mult; NR   0.94      0.45      0.67      0.92      0.16
# 01_s5r; mult; top20      1.00      0.46      0.76      0.45      0.19
# 01_s5r; mult; top20; NR  0.86      0.48      0.79      0.47      0.19
# 03_r5r; mult; top20      1.00      0.52      0.78      0.48      0.15
# 03_r5r; mult; top20; NR  0.94      0.53      0.79      0.50      0.15
# 04_g5r; mult; top20      1.00      0.35      0.63      0.35      0.19
# 04_g5r; mult; top20; NR  0.82      0.37      0.65      0.36      0.18
# 01_co75_s5r; mult        1.00      0.64      0.79      0.89      0.19
# 01_co75_s5r; mult; NR    0.86      0.68      0.82      0.91      0.20
#
#                          >0 wrcov  acc->0wc  mrr->0wc  arc->0wc  rnd->0wc  \
# 01_s5r; add                  0.97      0.64      0.77      0.92      0.20
# 01_s5r; add; NR              0.97      0.68      0.80      0.94      0.20
# 01_s5r; mult                 0.97      0.67      0.79      0.92      0.20
# 01_s5r; mult; NR             0.97      0.71      0.82      0.94      0.20
# 01_s5r; hmean                0.97      0.64      0.77      0.92      0.20
# 01_s5r; hmean; NR            0.97      0.68      0.80      0.94      0.20
# 02_s5s; add                  0.97      0.62      0.76      0.92      0.20
# 02_s5s; add; NR              0.97      0.66      0.79      0.94      0.20
# 02_s5s; mult                 0.97      0.65      0.78      0.92      0.20
# 02_s5s; mult; NR             0.97      0.69      0.81      0.94      0.20
# 02_s5s; hmean                0.97      0.63      0.76      0.92      0.20
# 02_s5s; hmean; NR            0.97      0.68      0.79      0.94      0.20
# 03_r5r; mult                 0.98      0.62      0.77      0.93      0.16
# 03_r5r; mult; NR             0.98      0.64      0.78      0.94      0.16
# 03_r5r->gr; mult             1.00      0.46      0.68      0.81      0.19
# 03_r5r->gr; mult; NR         1.00      0.48      0.69      0.82      0.19
# 04_g5r; mult                 1.00      0.43      0.65      0.87      0.19
# 04_g5r; mult; NR             1.00      0.45      0.67      0.88      0.19
# 04_g5r->rc; mult             0.98      0.49      0.68      0.92      0.16
# 04_g5r->rc; mult; NR         0.97      0.50      0.69      0.93      0.16
# 05_sr5r->s; mult             0.98      0.65      0.77      0.93      0.20
# 05_sr5r->s; mult; NR         0.97      0.69      0.81      0.95      0.20
# 05_sr5r->r; mult             0.98      0.64      0.78      0.94      0.16
# 05_sr5r->r; mult; NR         0.98      0.66      0.79      0.95      0.16
# 05_sr5r->g; mult             1.00      0.44      0.66      0.84      0.19
# 05_sr5r->g; mult; NR         1.00      0.46      0.67      0.85      0.19
# 10_srg5r->s; mult            0.98      0.63      0.76      0.94      0.20
# 10_srg5r->s; mult; NR        0.97      0.68      0.80      0.96      0.20
# 10_srg5r->r; mult            0.99      0.64      0.78      0.95      0.16
# 10_srg5r->r; mult; NR        0.99      0.66      0.79      0.96      0.16
# 10_srg5r->g; mult            1.00      0.47      0.68      0.90      0.19
# 10_srg5r->g; mult; NR        1.00      0.49      0.70      0.92      0.19
# 11_rg5r->s; mult             0.85      0.33      0.52      0.85      0.19
# 11_rg5r->s; mult; NR         0.83      0.36      0.55      0.87      0.19
# 11_rg5r->r; mult             0.98      0.63      0.78      0.95      0.16
# 11_rg5r->r; mult; NR         0.98      0.65      0.79      0.96      0.16
# 11_rg5r->g; mult             1.00      0.47      0.68      0.89      0.19
# 11_rg5r->g; mult; NR         1.00      0.49      0.69      0.90      0.19
# max area; s                  1.00      0.19      0.41      1.00      0.20
# max area; s; NR              1.00      0.20      0.43      1.00      0.20
# max area; c                  1.00      0.27      0.54      1.00      0.16
# max area; c; NR              1.00      0.28      0.55      1.00      0.16
# 06_pos_s5r; mult             0.97      0.62      0.76      0.92      0.20
# 06_pos_s5r; mult; NR         0.97      0.64      0.78      0.94      0.20
# 07_nopos_s5r; mult           0.97      0.55      0.71      0.92      0.20
# 07_nopos_s5r; mult; NR       0.97      0.58      0.73      0.94      0.20
# 08_pos_r5r; mult             0.98      0.56      0.74      0.93      0.16
# 08_pos_r5r; mult; NR         0.98      0.58      0.75      0.94      0.16
# 09_nopos_r5r; mult           0.98      0.44      0.66      0.93      0.16
# 09_nopos_r5r; mult; NR       0.98      0.46      0.67      0.94      0.16
# 01_s5r; mult; top20          0.74      0.62      0.76      0.61      0.19
# 01_s5r; mult; top20; NR      0.72      0.66      0.79      0.65      0.19
# 03_r5r; mult; top20          0.82      0.63      0.78      0.59      0.15
# 03_r5r; mult; top20; NR      0.82      0.65      0.79      0.60      0.15
# 04_g5r; mult; top20          0.88      0.40      0.63      0.40      0.19
# 04_g5r; mult; top20; NR      0.88      0.42      0.65      0.41      0.18
# 01_co75_s5r; mult            0.97      0.66      0.79      0.92      0.19
# 01_co75_s5r; mult; NR        0.97      0.70      0.82      0.94      0.20
#
#                          acc-b1-2  12%  acc-b3-4  34%  acc-b5-6  56%
# 01_s5r; add                  0.77 0.41      0.63 0.32      0.50 0.15
# 01_s5r; add; NR              0.77 0.47      0.65 0.33      0.54 0.13
# 01_s5r; mult                 0.78 0.41      0.67 0.32      0.54 0.15
# 01_s5r; mult; NR             0.78 0.47      0.69 0.33      0.57 0.13
# 01_s5r; hmean                0.77 0.41      0.64 0.32      0.48 0.15
# 01_s5r; hmean; NR            0.77 0.47      0.66 0.33      0.53 0.13
# 02_s5s; add                  0.77 0.41      0.61 0.32      0.45 0.15
# 02_s5s; add; NR              0.77 0.47      0.63 0.33      0.48 0.13
# 02_s5s; mult                 0.78 0.41      0.65 0.32      0.51 0.15
# 02_s5s; mult; NR             0.78 0.47      0.67 0.33      0.55 0.13
# 02_s5s; hmean                0.77 0.41      0.62 0.32      0.47 0.15
# 02_s5s; hmean; NR            0.77 0.47      0.65 0.33      0.51 0.13
# 03_r5r; mult                 0.72 0.35      0.64 0.40      0.51 0.16
# 03_r5r; mult; NR             0.72 0.37      0.65 0.42      0.53 0.14
# 03_r5r->gr; mult             0.56 0.02      0.51 0.11      0.50 0.22
# 03_r5r->gr; mult; NR         0.56 0.02      0.52 0.13      0.52 0.24
# 04_g5r; mult                 0.45 0.02      0.46 0.11      0.45 0.22
# 04_g5r; mult; NR             0.45 0.02      0.47 0.13      0.46 0.24
# 04_g5r->rc; mult             0.60 0.34      0.48 0.41      0.38 0.16
# 04_g5r->rc; mult; NR         0.60 0.37      0.48 0.42      0.40 0.15
# 05_sr5r->s; mult             0.77 0.41      0.65 0.32      0.51 0.15
# 05_sr5r->s; mult; NR         0.78 0.48      0.68 0.33      0.55 0.12
# 05_sr5r->r; mult             0.73 0.35      0.66 0.40      0.53 0.16
# 05_sr5r->r; mult; NR         0.73 0.37      0.67 0.42      0.55 0.14
# 05_sr5r->g; mult             0.49 0.02      0.48 0.11      0.48 0.22
# 05_sr5r->g; mult; NR         0.49 0.02      0.49 0.13      0.49 0.24
# 10_srg5r->s; mult            0.76 0.41      0.64 0.32      0.48 0.15
# 10_srg5r->s; mult; NR        0.76 0.48      0.67 0.33      0.53 0.12
# 10_srg5r->r; mult            0.72 0.35      0.66 0.40      0.52 0.16
# 10_srg5r->r; mult; NR        0.72 0.37      0.67 0.41      0.56 0.14
# 10_srg5r->g; mult            0.52 0.02      0.54 0.11      0.50 0.22
# 10_srg5r->g; mult; NR        0.52 0.02      0.55 0.13      0.52 0.24
# 11_rg5r->s; mult             0.47 0.33      0.34 0.36      0.21 0.17
# 11_rg5r->s; mult; NR         0.47 0.39      0.35 0.39      0.21 0.15
# 11_rg5r->r; mult             0.72 0.35      0.65 0.40      0.53 0.16
# 11_rg5r->r; mult; NR         0.72 0.37      0.65 0.42      0.56 0.14
# 11_rg5r->g; mult             0.47 0.02      0.52 0.11      0.52 0.22
# 11_rg5r->g; mult; NR         0.47 0.02      0.52 0.13      0.53 0.24
# max area; s                  0.29 0.43      0.15 0.32      0.09 0.15
# max area; s; NR              0.29 0.49      0.14 0.32      0.08 0.12
# max area; c                  0.38 0.36      0.25 0.40      0.17 0.15
# max area; c; NR              0.38 0.38      0.25 0.41      0.18 0.14
# 06_pos_s5r; mult             0.68 0.41      0.64 0.32      0.52 0.15
# 06_pos_s5r; mult; NR         0.68 0.47      0.66 0.33      0.56 0.13
# 07_nopos_s5r; mult           0.71 0.41      0.49 0.32      0.40 0.15
# 07_nopos_s5r; mult; NR       0.71 0.47      0.51 0.33      0.41 0.13
# 08_pos_r5r; mult             0.65 0.35      0.58 0.40      0.46 0.16
# 08_pos_r5r; mult; NR         0.65 0.37      0.59 0.42      0.48 0.14
# 09_nopos_r5r; mult           0.53 0.35      0.44 0.40      0.37 0.16
# 09_nopos_r5r; mult; NR       0.53 0.37      0.44 0.42      0.38 0.14
# 01_s5r; mult; top20          0.82 0.30      0.61 0.37      0.50 0.18
# 01_s5r; mult; top20; NR      0.82 0.35      0.62 0.40      0.52 0.16
# 03_r5r; mult; top20          0.77 0.28      0.64 0.44      0.51 0.18
# 03_r5r; mult; top20; NR      0.77 0.30      0.65 0.46      0.52 0.17
# 04_g5r; mult; top20          0.39 0.01      0.44 0.08      0.43 0.20
# 04_g5r; mult; top20; NR      0.39 0.01      0.44 0.09      0.44 0.24
# 01_co75_s5r; mult            0.78 0.40      0.66 0.33      0.53 0.15
# 01_co75_s5r; mult; NR        0.78 0.47      0.69 0.34      0.56 0.13

# %%
index = []
rows = []
for model, rdf in results:
    if 'rprop' in model:
        index.append(model)
        rows.append(summarise_rdf_rprop(rdf))
        index.append(model+'; no rel')
        rows.append(summarise_rdf_rprop(rdf.query('is_rel == False')))

collected_columns = {}
for this_row in rows:
    for this_key, this_val in this_row.items():
        this_list = collected_columns.get(this_key, list())
        this_list.append(this_val)
        collected_columns[this_key] = this_list
        
full_df_rp = pd.DataFrame(collected_columns, index=index)

# %%
full_df_rp[['RP@1-full', 'RP@10-full', 'arc-full', 'rnd-full', '>0 wrcov',
            'RP@1->0wc', 'RP@10->0wc', 'arc->0wc', 'rnd->0wc']]
# Out:
#                                     RP@1-full  RP@10-full  arc-full  rnd-full  \
# 01_s5r; brprop; mult                     0.09        0.24      0.88      0.03
# 01_s5r; brprop; mult; no rel             0.10        0.26      0.90      0.03
# 05_sr5r; brprop; mult                    0.09        0.24      0.90      0.03
# 05_sr5r; brprop; mult; no rel            0.10        0.26      0.92      0.03
# 03_r5r; grprop; mult                     0.52        0.77      0.91      0.17
# 03_r5r; grprop; mult; no rel             0.54        0.78      0.92      0.17
# 09_nopos_r5r; grprop; mult               0.38        0.77      0.91      0.17
# 09_nopos_r5r; grprop; mult; no rel       0.39        0.78      0.92      0.17
# 08_pos_r5r; grprop; mult                 0.48        0.77      0.91      0.17
# 08_pos_r5r; grprop; mult; no rel         0.49        0.78      0.92      0.17
# 04_g5r; grprop; mult                     0.36        0.75      0.86      0.16
# 04_g5r; grprop; mult; no rel             0.37        0.75      0.88      0.17
#
#                                     >0 wrcov  RP@1->0wc  RP@10->0wc  arc->0wc  \
# 01_s5r; brprop; mult                    0.97       0.09        0.25      0.92
# 01_s5r; brprop; mult; no rel            0.96       0.10        0.27      0.94
# 05_sr5r; brprop; mult                   0.97       0.10        0.25      0.93
# 05_sr5r; brprop; mult; no rel           0.97       0.10        0.26      0.95
# 03_r5r; grprop; mult                    0.98       0.54        0.79      0.93
# 03_r5r; grprop; mult; no rel            0.98       0.55        0.80      0.94
# 09_nopos_r5r; grprop; mult              0.98       0.39        0.79      0.93
# 09_nopos_r5r; grprop; mult; no rel      0.98       0.40        0.80      0.94
# 08_pos_r5r; grprop; mult                0.98       0.49        0.79      0.93
# 08_pos_r5r; grprop; mult; no rel        0.98       0.51        0.80      0.94
# 04_g5r; grprop; mult                    1.00       0.36        0.75      0.87
# 04_g5r; grprop; mult; no rel            0.99       0.37        0.76      0.88
#
#                                     rnd->0wc
# 01_s5r; brprop; mult                    0.03
# 01_s5r; brprop; mult; no rel            0.03
# 05_sr5r; brprop; mult                   0.04
# 05_sr5r; brprop; mult; no rel           0.04
# 03_r5r; grprop; mult                    0.17
# 03_r5r; grprop; mult; no rel            0.18
# 09_nopos_r5r; grprop; mult              0.17
# 09_nopos_r5r; grprop; mult; no rel      0.18
# 08_pos_r5r; grprop; mult                0.17
# 08_pos_r5r; grprop; mult; no rel        0.18
# 04_g5r; grprop; mult                    0.17
# 04_g5r; grprop; mult; no rel            0.17

# %%
with gzip.open('EvalOut/full_df_precomp.pklz', 'w') as f:
    pickle.dump((full_df, full_df_rp), f)

# %% [markdown]
# ### Some post-hoc analysis
#
# #### Max Area for grexp

# %%
r01 = res_dict['01_s5r; mult']

# %%
len(res_dict['03_r5r; mult'])
# Out:
# 10834

# %%
r03 = res_dict['03_r5r; mult']

# %%
len(res_dict['04_g5r; mult'])
# Out:
# 4849

# %%
r04 = res_dict['04_g5r; mult']
r04_filelist = list(set(r04['image_id'].tolist()))

# %%
len(res_dict['max area; c'])
# Out:
# 10834

# %%
len(res_dict['max area; c'][res_dict['max area; c']['image_id'].isin(r04_filelist)])
# Out:
# 7469

# %%
grex_maxarea = res_dict['max area; c'][res_dict['max area; c']['image_id'].isin(r04_filelist)]

# %%
np.sum(grex_maxarea['suc']) / len(grex_maxarea)
# Out:
# 0.19627794885526845

# %%
len(grex_maxarea['image_id'].unique())
# Out:
# 1103

# %%
mrr_f(r04.groupby('image_id').first().reset_index()['nob'])
# Out:
# 0.19912366024671468

# %%
mrr_f(r03.groupby('image_id').first().reset_index()['nob'])
# Out:
# 0.17035588398429238

# %%
ma_red = res_dict['max area; c'].groupby('image_id').first().reset_index()
np.count_nonzero(ma_red['suc']) / len(ma_red)
# Out:
# 0.23266666666666666

# %% [markdown]
# Double checking stuff:

# %%
len(r03.query('cov > 0')) / len(r03)
# Out:
# 0.9800627653682851

# %%
len(r03.query('cov > 0 & is_rel == False')) / len(r03.query('is_rel == False'))
# Out:
# 0.979234009207562

# %%
len(r04.query('cov > 0')) / len(r04)
# Out:
# 0.9973190348525469

# %%
len(r01.query('cov > 0')) / len(r01)
# Out:
# 0.9697751873438801

# %%
len(r01.query('cov > 0 & is_rel == False')) / len(r01.query('is_rel == False'))
# Out:
# 0.9663646877409406

# %% [markdown]
# #### region props
#
# why are scores lower for >0 wc?
#
# FIXED. NANs count as non_zero. Must replace them with zero first.

# %%
r01rp = res_dict['01_s5r; brprop; mult']

# %%
np.isnan(r01rp.apply(is_iou_over_threshold_top_n, axis=1).tolist()).any()
# Out:
# True
